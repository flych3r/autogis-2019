# %%
# Download data
# !wget 'https://github.com/AutoGIS/data/raw/master/L2_data.zip'
# !unzip -o -q 'L2_data.zip'
# !rm 'L2_data.zip'

# %%
import geopandas as gpd
gpd.io.file.fiona.drvsupport.supported_drivers
# Out:
# {'AeronavFAA': 'r',
#  'ARCGEN': 'r',
#  'BNA': 'raw',
#  'DXF': 'raw',
#  'CSV': 'raw',
#  'OpenFileGDB': 'r',
#  'ESRIJSON': 'r',
#  'ESRI Shapefile': 'raw',
#  'GeoJSON': 'rw',
#  'GeoJSONSeq': 'rw',
#  'GPKG': 'rw',
#  'GML': 'raw',
#  'GPX': 'raw',
#  'GPSTrackMaker': 'raw',
#  'Idrisi': 'r',
#  'MapInfo File': 'raw',
#  'DGN': 'raw',
#  'PCIDSK': 'r',
#  'S57': 'r',
#  'SEGY': 'r',
#  'SUA': 'r',
#  'TopoJSON': 'r'}

# %%
data = gpd.read_file('L2_data/Europe_borders.shp')
data.head()
# Out:
#             TZID                                           geometry
# 0  Europe/Berlin  POLYGON ((8.45778 54.56236, 8.44953 54.56269, ...
# 1  Europe/Berlin  POLYGON ((8.71992 47.69664, 8.72092 47.69530, ...
# 2  Europe/Berlin  POLYGON ((6.73317 53.57409, 6.73017 53.57542, ...
# 3  Europe/Berlin  POLYGON ((6.85822 53.59411, 6.85592 53.59550, ...
# 4  Europe/Berlin  POLYGON ((6.89894 53.62561, 6.88439 53.62814, ...

# %%
data.to_file('L2_data/Europe_borders_copy.shp')

# %%
data.plot()
